# %%
tpl=()
tpl1=tuple()
print(type(tpl),type(tpl1))
# Out:
# <class 'tuple'> <class 'tuple'>

# %%
tpl=(1,2,3,4,"hello")
print(tpl)
# Out:
# (1, 2, 3, 4, 'hello')

# %%
tpl=(3,4,5,7,4,[5,5,6,7])
# tpl[3]=70
tpl[-1][1]=40
print(tpl)
# Out:
# (3, 4, 5, 7, 4, [5, 40, 6, 7])

# %%
tpl=(2,3,4,5,4,)
print(id(tpl))
tpl+=("hello",5,7,8)
print(id(tpl))
print(tpl)
# Out:
# 4420956704
# 4419741616
# (2, 3, 4, 5, 4, 'hello', 5, 7, 8)

# %%
tpl=(1,4,5,3,8,5,6,4,9)
del tpl
# print(tpl)

# %%
tpl=(1,4,5,3,8,5,6,4,9)
tpl.count
print(tpl)
# Out:
# (1, 4, 5, 3, 8, 5, 6, 4, 9)

# %%
tpl=(1,4,5,3,8,5,6,4,9)
tpl1=(sorted(tpl,reverse=True))
print(tuple(tpl1))
# Out:
# (9, 8, 6, 5, 5, 4, 4, 3, 1)
